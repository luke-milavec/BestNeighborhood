# %%
import pandas as pd

# %%
education = pd.read_csv("./data/education-income.csv")
education
# Out:
#            Neighborhood  Sector # Population (2010)  \
# 0      Allegheny Center         3               933
# 1        Allegheny West         3               462
# 2             Allentown         6             2,500
# 3             Arlington         7             1,869
# 4     Arlington Heights         7               244
# ..                  ...       ...               ...
# 85  Upper Lawrenceville        13             2,669
# 86             West End         4               254
# 87         West Oakland        14             2,604
# 88             Westwood         4             3,066
# 89              Windgap         4             1,369
#
#    Total Pop, 25 and older (2010)  \
# 0                             609
# 1                             239
# 2                           1,729
# 3                           1,232
# 4                             166
# ..                            ...
# 85                          1,875
# 86                             86
# ...
